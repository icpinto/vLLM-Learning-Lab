# %% [markdown]
# # 00 — Environment Check
#
# Goal: verify Python, PyTorch, CUDA, GPU memory, package imports, and config loading before running the real experiments.

# %%
import sys
from pathlib import Path

# Add local src path if the package is not installed yet.
repo_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(repo_root / 'src'))

from vllm_lab.utils import environment_report, load_config

report = environment_report()
report

# %%
config = load_config(repo_root / 'configs' / 'lab_config.yaml')
config

# %% [markdown]
# Interpretation: if CUDA is unavailable, the lab can still be read and some simulations can run, but the vLLM/Transformers speed comparisons will not represent GPU serving performance.

# %%
# Optional: check vLLM import.
try:
    import vllm
    print('vLLM import OK:', getattr(vllm, '__version__', 'unknown'))
except Exception as exc:
    print('vLLM import failed:', exc)
    print('Install with: pip install -r requirements.txt')
