# %% [markdown]
# # 08 — Gradio Monitoring Dashboard
#
# Goal: run the capstone dashboard that reads stress-test result CSV files and summarises latency and throughput.

# %% [markdown]
# From the repo root, run:
#
# ```bash
# python dashboard/app.py
# ```
#
# Then open the local Gradio URL printed in the terminal.

# %%
import sys
from pathlib import Path
repo_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(repo_root))
sys.path.insert(0, str(repo_root / 'src'))

from dashboard.app import summarize

raw, summary, note = summarize()
print(note)
summary

# %% [markdown]
# Capstone task: run the stress test under at least three server configurations, refresh the dashboard, and write down which configuration you would choose for a 10-user internal demo. Defend the choice using measured latency and throughput.
